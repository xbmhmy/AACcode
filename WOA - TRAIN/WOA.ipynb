# %%
import shap
import xgboost
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pylab as pl
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
# print the JS visualization code to the notebook
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# %run TunedXgboost.py
# Out:
# [0]	train-rmse:36.42352	test-rmse:37.20047
# [1]	train-rmse:32.49550	test-rmse:33.29290
# [2]	train-rmse:29.14759	test-rmse:29.99135
# [3]	train-rmse:26.39034	test-rmse:27.26221
# [4]	train-rmse:23.91472	test-rmse:24.82711
# [5]	train-rmse:21.77891	test-rmse:22.72548
# [6]	train-rmse:19.93019	test-rmse:20.89262
# [7]	train-rmse:18.32255	test-rmse:19.35124
# [8]	train-rmse:16.88607	test-rmse:18.01061
# [9]	train-rmse:15.75521	test-rmse:16.91620
# [10]	train-rmse:14.77005	test-rmse:15.95355
# [11]	train-rmse:13.97439	test-rmse:15.17485
# [12]	train-rmse:13.13689	test-rmse:14.39624
# [13]	train-rmse:12.38712	test-rmse:13.71762
# [14]	train-rmse:11.78541	test-rmse:13.12885
# [15]	train-rmse:11.21945	test-rmse:12.59525
# [16]	train-rmse:10.79584	test-rmse:12.17182
# [17]	train-rmse:10.35249	test-rmse:11.75504
# [18]	train-rmse:9.98517	test-rmse:11.41578
# [19]	train-rmse:9.63991	test-rmse:11.08949
# [20]	train-rmse:9.33898	test-rmse:10.83894
# [21]	train-rmse:9.05183	test-rmse:10.56940
# [22]	train-rmse:8.82224	test-rmse:10.38999
# [23]	train-rmse:8.58344	test-rmse:10.17039
# [24]	train-rmse:8.36862	test-rmse:9.94327
# [25]	train-rmse:8.15407	test-rmse:9.73934
# [26]	train-rmse:7.99230	test-rmse:9.59832
# [27]	train-rmse:7.82498	test-rmse:9.45931
# [28]	train-rmse:7.65022	test-rmse:9.31839
# [29]	train-rmse:7.50470	test-rmse:9.19492
# [30]	train-rmse:7.34442	test-rmse:9.04378
# [31]	train-rmse:7.21545	test-rmse:8.91434
# [32]	train-rmse:7.09455	test-rmse:8.81826
# [33]	train-rmse:6.97351	test-rmse:8.71619
# [34]	train-rmse:6.86498	test-rmse:8.63761
# [35]	train-rmse:6.74237	test-rmse:8.52788
# [36]	train-rmse:6.64085	test-rmse:8.44362
# [37]	train-rmse:6.54882	test-rmse:8.35854
# [38]	train-rmse:6.45052	test-rmse:8.26786
# [39]	train-rmse:6.35945	test-rmse:8.19051
# [40]	train-rmse:6.27225	test-rmse:8.13345
# [41]	train-rmse:6.18929	test-rmse:8.08348
# [42]	train-rmse:6.11040	test-rmse:8.02240
# [43]	train-rmse:6.04157	test-rmse:7.95379
# [44]	train-rmse:5.96138	test-rmse:7.89884
# [45]	train-rmse:5.89005	test-rmse:7.83976
# [46]	train-rmse:5.83179	test-rmse:7.80267
# [47]	train-rmse:5.77678	test-rmse:7.77884
# [48]	train-rmse:5.70937	test-rmse:7.72274
# [49]	train-rmse:5.63697	test-rmse:7.65916
# [50]	train-rmse:5.57794	test-rmse:7.62405
# [51]	train-rmse:5.53639	test-rmse:7.59777
# [52]	train-rmse:5.48174	test-rmse:7.57444
# [53]	train-rmse:5.42359	test-rmse:7.54829
# [54]	train-rmse:5.38034	test-rmse:7.50996
# [55]	train-rmse:5.32616	test-rmse:7.48975
# [56]	train-rmse:5.28367	test-rmse:7.45780
# [57]	train-rmse:5.23400	test-rmse:7.42020
# [58]	train-rmse:5.18988	test-rmse:7.38048
# [59]	train-rmse:5.14833	test-rmse:7.36112
# [60]	train-rmse:5.10529	test-rmse:7.33780
# [61]	train-rmse:5.06145	test-rmse:7.30696
# [62]	train-rmse:5.01828	test-rmse:7.27343
# [63]	train-rmse:4.97206	test-rmse:7.23075
# [64]	train-rmse:4.93015	test-rmse:7.19536
# [65]	train-rmse:4.88858	test-rmse:7.15584
# [66]	train-rmse:4.84865	test-rmse:7.13069
# [67]	train-rmse:4.81465	test-rmse:7.12660
# [68]	train-rmse:4.78054	test-rmse:7.10793
# [69]	train-rmse:4.74628	test-rmse:7.09571
# [70]	train-rmse:4.71402	test-rmse:7.06180
# [71]	train-rmse:4.68144	test-rmse:7.03426
# [72]	train-rmse:4.65218	test-rmse:7.02853
# [73]	train-rmse:4.61641	test-rmse:6.99601
# [74]	train-rmse:4.58117	test-rmse:6.97106
# [75]	train-rmse:4.54996	test-rmse:6.96149
# [76]	train-rmse:4.52021	test-rmse:6.94647
# [77]	train-rmse:4.49149	test-rmse:6.92532
# [78]	train-rmse:4.46224	test-rmse:6.90287
# [79]	train-rmse:4.44199	test-rmse:6.89418
# [80]	train-rmse:4.42456	test-rmse:6.87862
# [81]	train-rmse:4.39606	test-rmse:6.86700
# [82]	train-rmse:4.37220	test-rmse:6.85008
# [83]	train-rmse:4.35163	test-rmse:6.83706
# [84]	train-rmse:4.33247	test-rmse:6.81895
# [85]	train-rmse:4.31202	test-rmse:6.80360
# [86]	train-rmse:4.28942	test-rmse:6.81055
# [87]	train-rmse:4.26056	test-rmse:6.79738
# [88]	train-rmse:4.23937	test-rmse:6.78470
# [89]	train-rmse:4.21132	test-rmse:6.77317
# [90]	train-rmse:4.19380	test-rmse:6.76792
# [91]	train-rmse:4.17538	test-rmse:6.76435
# [92]	train-rmse:4.15349	test-rmse:6.75956
# [93]	train-rmse:4.13295	test-rmse:6.75198
# [94]	train-rmse:4.11262	test-rmse:6.74767
# [95]	train-rmse:4.08787	test-rmse:6.74161
# [96]	train-rmse:4.06405	test-rmse:6.73547
# [97]	train-rmse:4.04280	test-rmse:6.71229
# [98]	train-rmse:4.01884	test-rmse:6.70244
# [99]	train-rmse:4.00107	test-rmse:6.69399
# [100]	train-rmse:3.98059	test-rmse:6.69212
# [101]	train-rmse:3.95657	test-rmse:6.67659
# [102]	train-rmse:3.93695	test-rmse:6.66604
# [103]	train-rmse:3.91481	test-rmse:6.66633
# [104]	train-rmse:3.89221	test-rmse:6.65500
# [105]	train-rmse:3.87331	test-rmse:6.64826
# [106]	train-rmse:3.85790	test-rmse:6.64731
# [107]	train-rmse:3.83392	test-rmse:6.64487
# [108]	train-rmse:3.81300	test-rmse:6.63292
# [109]	train-rmse:3.79551	test-rmse:6.63563
# [110]	train-rmse:3.77907	test-rmse:6.62370
# [111]	train-rmse:3.75761	test-rmse:6.61724
# [112]	train-rmse:3.74240	test-rmse:6.61239
# [113]	train-rmse:3.72304	test-rmse:6.60768
# [114]	train-rmse:3.70986	test-rmse:6.60873
# [115]	train-rmse:3.68999	test-rmse:6.60568
# [116]	train-rmse:3.67784	test-rmse:6.59439
# [117]	train-rmse:3.66523	test-rmse:6.59162
# [118]	train-rmse:3.65001	test-rmse:6.58913
# [119]	train-rmse:3.63494	test-rmse:6.58765
# [120]	train-rmse:3.62054	test-rmse:6.57596
# [121]	train-rmse:3.60155	test-rmse:6.56840
# [122]	train-rmse:3.58526	test-rmse:6.57203
# [123]	train-rmse:3.56833	test-rmse:6.56883
# [124]	train-rmse:3.55481	test-rmse:6.55724
# [125]	train-rmse:3.53511	test-rmse:6.55139
# [126]	train-rmse:3.52139	test-rmse:6.54074
# [127]	train-rmse:3.50600	test-rmse:6.54185
# [128]	train-rmse:3.48966	test-rmse:6.53631
# [129]	train-rmse:3.48017	test-rmse:6.53478
# [130]	train-rmse:3.46113	test-rmse:6.53024
# [131]	train-rmse:3.45010	test-rmse:6.52437
# [132]	train-rmse:3.43334	test-rmse:6.51996
# [133]	train-rmse:3.42244	test-rmse:6.51249
# [134]	train-rmse:3.40551	test-rmse:6.51612
# [135]	train-rmse:3.39765	test-rmse:6.51392
# [136]	train-rmse:3.38158	test-rmse:6.51285
# [137]	train-rmse:3.37259	test-rmse:6.51082
# [138]	train-rmse:3.35953	test-rmse:6.51035
# [139]	train-rmse:3.34352	test-rmse:6.49926
# [140]	train-rmse:3.32885	test-rmse:6.49745
# [141]	train-rmse:3.31723	test-rmse:6.49624
# [142]	train-rmse:3.30495	test-rmse:6.49083
# [143]	train-rmse:3.29517	test-rmse:6.48764
# [144]	train-rmse:3.28133	test-rmse:6.47814
# [145]	train-rmse:3.27033	test-rmse:6.48525
# [146]	train-rmse:3.25869	test-rmse:6.48431
# [147]	train-rmse:3.24751	test-rmse:6.47889
# [148]	train-rmse:3.23612	test-rmse:6.47222
# [149]	train-rmse:3.22781	test-rmse:6.46861
# [150]	train-rmse:3.21785	test-rmse:6.47756
# [151]	train-rmse:3.20665	test-rmse:6.46900
# [152]	train-rmse:3.19695	test-rmse:6.45706
# [153]	train-rmse:3.18559	test-rmse:6.45461
# [154]	train-rmse:3.17307	test-rmse:6.45160
# [155]	train-rmse:3.16141	test-rmse:6.44447
# [156]	train-rmse:3.15006	test-rmse:6.45120
# [157]	train-rmse:3.13602	test-rmse:6.45548
# [158]	train-rmse:3.12758	test-rmse:6.45625
# [159]	train-rmse:3.11680	test-rmse:6.46207
# [160]	train-rmse:3.10390	test-rmse:6.45945
# [161]	train-rmse:3.09679	test-rmse:6.45493
# [162]	train-rmse:3.08717	test-rmse:6.45177
# [163]	train-rmse:3.07749	test-rmse:6.44562
# [164]	train-rmse:3.06424	test-rmse:6.43708
# [165]	train-rmse:3.05513	test-rmse:6.43227
# [166]	train-rmse:3.04719	test-rmse:6.43007
# [167]	train-rmse:3.03784	test-rmse:6.42429
# [168]	train-rmse:3.02752	test-rmse:6.42159
# [169]	train-rmse:3.01875	test-rmse:6.42334
# [170]	train-rmse:3.01249	test-rmse:6.42317
# [171]	train-rmse:3.00391	test-rmse:6.42374
# [172]	train-rmse:2.99557	test-rmse:6.42734
# [173]	train-rmse:2.98595	test-rmse:6.42367
# [174]	train-rmse:2.98057	test-rmse:6.42528
# [175]	train-rmse:2.96918	test-rmse:6.41983
# [176]	train-rmse:2.96108	test-rmse:6.42464
# [177]	train-rmse:2.95238	test-rmse:6.42374
# [178]	train-rmse:2.94390	test-rmse:6.42293
# [179]	train-rmse:2.93612	test-rmse:6.42208
# [180]	train-rmse:2.92853	test-rmse:6.42735
# [181]	train-rmse:2.91992	test-rmse:6.42269
# [182]	train-rmse:2.91222	test-rmse:6.42496
# [183]	train-rmse:2.90153	test-rmse:6.41601
# [184]	train-rmse:2.89218	test-rmse:6.41738
# [185]	train-rmse:2.88558	test-rmse:6.42109
# [186]	train-rmse:2.87642	test-rmse:6.42545
# [187]	train-rmse:2.86694	test-rmse:6.42042
# [188]	train-rmse:2.85634	test-rmse:6.41261
# [189]	train-rmse:2.84939	test-rmse:6.41149
# [190]	train-rmse:2.84038	test-rmse:6.41431
# [191]	train-rmse:2.83114	test-rmse:6.41141
# [192]	train-rmse:2.82441	test-rmse:6.41388
# [193]	train-rmse:2.81645	test-rmse:6.41193
# [194]	train-rmse:2.80882	test-rmse:6.40749
# [195]	train-rmse:2.80162	test-rmse:6.40555
# [196]	train-rmse:2.79239	test-rmse:6.40375
# [197]	train-rmse:2.78387	test-rmse:6.40040
# [198]	train-rmse:2.77460	test-rmse:6.39531
# [199]	train-rmse:2.76721	test-rmse:6.38974
# [200]	train-rmse:2.76053	test-rmse:6.38526
# [201]	train-rmse:2.75131	test-rmse:6.38241
# [202]	train-rmse:2.74416	test-rmse:6.38156
# [203]	train-rmse:2.73544	test-rmse:6.37815
# [204]	train-rmse:2.72357	test-rmse:6.37147
# [205]	train-rmse:2.71737	test-rmse:6.37217
# [206]	train-rmse:2.70992	test-rmse:6.36760
# [207]	train-rmse:2.70282	test-rmse:6.36312
# [208]	train-rmse:2.69755	test-rmse:6.36620
# [209]	train-rmse:2.69267	test-rmse:6.36307
# [210]	train-rmse:2.68483	test-rmse:6.35471
# [211]	train-rmse:2.67994	test-rmse:6.35467
# [212]	train-rmse:2.67447	test-rmse:6.35842
# [213]	train-rmse:2.66955	test-rmse:6.36012
# [214]	train-rmse:2.66290	test-rmse:6.36035
# [215]	train-rmse:2.65555	test-rmse:6.36074
# [216]	train-rmse:2.64873	test-rmse:6.36073
# [217]	train-rmse:2.64325	test-rmse:6.36062
# [218]	train-rmse:2.63847	test-rmse:6.36140
# [219]	train-rmse:2.63226	test-rmse:6.36533
# [220]	train-rmse:2.62631	test-rmse:6.36129
# [221]	train-rmse:2.61910	test-rmse:6.35866
# [222]	train-rmse:2.61512	test-rmse:6.35462
# [223]	train-rmse:2.61039	test-rmse:6.35619
# [224]	train-rmse:2.60330	test-rmse:6.35143
# [225]	train-rmse:2.59632	test-rmse:6.35223
# [226]	train-rmse:2.59070	test-rmse:6.35349
# [227]	train-rmse:2.58472	test-rmse:6.34820
# [228]	train-rmse:2.57726	test-rmse:6.35265
# [229]	train-rmse:2.57277	test-rmse:6.34675
# [230]	train-rmse:2.56785	test-rmse:6.35252
# [231]	train-rmse:2.56241	test-rmse:6.35030
# [232]	train-rmse:2.55580	test-rmse:6.34550
# [233]	train-rmse:2.55065	test-rmse:6.34581
# [234]	train-rmse:2.54459	test-rmse:6.34307
# [235]	train-rmse:2.53476	test-rmse:6.33714
# [236]	train-rmse:2.52808	test-rmse:6.33585
# [237]	train-rmse:2.52273	test-rmse:6.33471
# [238]	train-rmse:2.51683	test-rmse:6.33647
# [239]	train-rmse:2.51093	test-rmse:6.33440
# [240]	train-rmse:2.50428	test-rmse:6.33471
# [241]	train-rmse:2.49723	test-rmse:6.33289
# [242]	train-rmse:2.49198	test-rmse:6.33650
# [243]	train-rmse:2.48748	test-rmse:6.33134
# [244]	train-rmse:2.47972	test-rmse:6.32914
# [245]	train-rmse:2.47407	test-rmse:6.32742
# [246]	train-rmse:2.46771	test-rmse:6.32558
# [247]	train-rmse:2.46016	test-rmse:6.32251
# [248]	train-rmse:2.45400	test-rmse:6.32189
# [249]	train-rmse:2.44967	test-rmse:6.32035
# [250]	train-rmse:2.44378	test-rmse:6.32163
# [251]	train-rmse:2.43784	test-rmse:6.32313
# [252]	train-rmse:2.43225	test-rmse:6.32599
# [253]	train-rmse:2.42842	test-rmse:6.31885
# [254]	train-rmse:2.42262	test-rmse:6.31909
# [255]	train-rmse:2.41618	test-rmse:6.31708
# [256]	train-rmse:2.40953	test-rmse:6.31638
# [257]	train-rmse:2.40431	test-rmse:6.31541
# [258]	train-rmse:2.39674	test-rmse:6.30651
# [259]	train-rmse:2.39017	test-rmse:6.30544
# [260]	train-rmse:2.38510	test-rmse:6.29793
# [261]	train-rmse:2.37798	test-rmse:6.29749
# [262]	train-rmse:2.37389	test-rmse:6.29849
# [263]	train-rmse:2.37048	test-rmse:6.30054
# [264]	train-rmse:2.36678	test-rmse:6.29208
# [265]	train-rmse:2.36141	test-rmse:6.29016
# [266]	train-rmse:2.35617	test-rmse:6.28886
# [267]	train-rmse:2.34994	test-rmse:6.28433
# [268]	train-rmse:2.34610	test-rmse:6.28775
# [269]	train-rmse:2.34201	test-rmse:6.29060
# [270]	train-rmse:2.33897	test-rmse:6.29013
# [271]	train-rmse:2.33487	test-rmse:6.29374
# [272]	train-rmse:2.33004	test-rmse:6.29143
# [273]	train-rmse:2.32413	test-rmse:6.28973
# [274]	train-rmse:2.31973	test-rmse:6.28448
# [275]	train-rmse:2.31632	test-rmse:6.28338
# [276]	train-rmse:2.31074	test-rmse:6.28082
# [277]	train-rmse:2.30444	test-rmse:6.28310
# [278]	train-rmse:2.30024	test-rmse:6.28206
# [279]	train-rmse:2.29772	test-rmse:6.28125
# [280]	train-rmse:2.29412	test-rmse:6.28226
# [281]	train-rmse:2.28997	test-rmse:6.28320
# [282]	train-rmse:2.28474	test-rmse:6.28795
# [283]	train-rmse:2.27953	test-rmse:6.28753
# [284]	train-rmse:2.27636	test-rmse:6.29105
# [285]	train-rmse:2.27325	test-rmse:6.29276
# [286]	train-rmse:2.26922	test-rmse:6.28148
# [287]	train-rmse:2.26472	test-rmse:6.28705
# [288]	train-rmse:2.26021	test-rmse:6.28518
# [289]	train-rmse:2.25468	test-rmse:6.28791
# [290]	train-rmse:2.25131	test-rmse:6.29001
# [291]	train-rmse:2.24500	test-rmse:6.28718
# [292]	train-rmse:2.23934	test-rmse:6.28782
# [293]	train-rmse:2.23515	test-rmse:6.29067
# [294]	train-rmse:2.22986	test-rmse:6.29086
# [295]	train-rmse:2.22495	test-rmse:6.28445
# [296]	train-rmse:2.22209	test-rmse:6.28160
# [297]	train-rmse:2.21740	test-rmse:6.27754
# [298]	train-rmse:2.21194	test-rmse:6.28337
# [299]	train-rmse:2.20870	test-rmse:6.28359
# [300]	train-rmse:2.20282	test-rmse:6.28446
# [301]	train-rmse:2.19838	test-rmse:6.28679
# [302]	train-rmse:2.19456	test-rmse:6.28273
# [303]	train-rmse:2.19084	test-rmse:6.28354
# [304]	train-rmse:2.18747	test-rmse:6.28300
# [305]	train-rmse:2.18346	test-rmse:6.28456
# [306]	train-rmse:2.17822	test-rmse:6.27922
# [307]	train-rmse:2.17464	test-rmse:6.28028
# [308]	train-rmse:2.17077	test-rmse:6.28161
# [309]	train-rmse:2.16416	test-rmse:6.27736
# [310]	train-rmse:2.16036	test-rmse:6.27998
# [311]	train-rmse:2.15689	test-rmse:6.27963
# [312]	train-rmse:2.15174	test-rmse:6.27704
# [313]	train-rmse:2.14726	test-rmse:6.27522
# [314]	train-rmse:2.14394	test-rmse:6.27738
# [315]	train-rmse:2.14041	test-rmse:6.27698
# [316]	train-rmse:2.13619	test-rmse:6.28124
# [317]	train-rmse:2.13176	test-rmse:6.28126
# [318]	train-rmse:2.12824	test-rmse:6.28219
# [319]	train-rmse:2.12430	test-rmse:6.28398
# [320]	train-rmse:2.11978	test-rmse:6.29053
# [321]	train-rmse:2.11603	test-rmse:6.29269
# [322]	train-rmse:2.11192	test-rmse:6.29271
# [323]	train-rmse:2.10848	test-rmse:6.28968
# [324]	train-rmse:2.10327	test-rmse:6.29128
# [325]	train-rmse:2.09922	test-rmse:6.28981
# [326]	train-rmse:2.09581	test-rmse:6.28901
# [327]	train-rmse:2.09271	test-rmse:6.29058
# [328]	train-rmse:2.08766	test-rmse:6.29165
# [329]	train-rmse:2.08436	test-rmse:6.28761
# [330]	train-rmse:2.08111	test-rmse:6.28752
# [331]	train-rmse:2.07773	test-rmse:6.28869
# [332]	train-rmse:2.07360	test-rmse:6.28537
# [333]	train-rmse:2.07086	test-rmse:6.28588
# [334]	train-rmse:2.06814	test-rmse:6.28466
# [335]	train-rmse:2.06497	test-rmse:6.28052
# [336]	train-rmse:2.06159	test-rmse:6.27733
# [337]	train-rmse:2.05847	test-rmse:6.27556
# [338]	train-rmse:2.05402	test-rmse:6.27842
# [339]	train-rmse:2.04892	test-rmse:6.27774
# [340]	train-rmse:2.04461	test-rmse:6.27471
# [341]	train-rmse:2.04126	test-rmse:6.27782
# [342]	train-rmse:2.03840	test-rmse:6.27510
# [343]	train-rmse:2.03673	test-rmse:6.27616
# [344]	train-rmse:2.03373	test-rmse:6.27503
# [345]	train-rmse:2.02988	test-rmse:6.26984
# [346]	train-rmse:2.02703	test-rmse:6.27159
# [347]	train-rmse:2.02298	test-rmse:6.27001
# [348]	train-rmse:2.01914	test-rmse:6.27177
# [349]	train-rmse:2.01440	test-rmse:6.26815
# [350]	train-rmse:2.01183	test-rmse:6.26615
# [351]	train-rmse:2.00873	test-rmse:6.26419
# [352]	train-rmse:2.00578	test-rmse:6.26656
# [353]	train-rmse:2.00161	test-rmse:6.26487
# [354]	train-rmse:1.99875	test-rmse:6.26878
# [355]	train-rmse:1.99667	test-rmse:6.26998
# [356]	train-rmse:1.99409	test-rmse:6.27162
# [357]	train-rmse:1.99097	test-rmse:6.27298
# [358]	train-rmse:1.98826	test-rmse:6.27541
# [359]	train-rmse:1.98550	test-rmse:6.27840
# [360]	train-rmse:1.98282	test-rmse:6.27778
# [361]	train-rmse:1.98001	test-rmse:6.27986
# [362]	train-rmse:1.97717	test-rmse:6.28264
# [363]	train-rmse:1.97491	test-rmse:6.28209
# [364]	train-rmse:1.97159	test-rmse:6.28173
# [365]	train-rmse:1.96835	test-rmse:6.28191
# [366]	train-rmse:1.96548	test-rmse:6.27881
# [367]	train-rmse:1.96271	test-rmse:6.28045
# [368]	train-rmse:1.95894	test-rmse:6.27695
# [369]	train-rmse:1.95572	test-rmse:6.27670
# [370]	train-rmse:1.95236	test-rmse:6.27504
# [371]	train-rmse:1.94956	test-rmse:6.27712
# [372]	train-rmse:1.94717	test-rmse:6.27443
# [373]	train-rmse:1.94397	test-rmse:6.27906
# [374]	train-rmse:1.94090	test-rmse:6.27800
# [375]	train-rmse:1.93784	test-rmse:6.27870
# [376]	train-rmse:1.93535	test-rmse:6.27732
# [377]	train-rmse:1.93266	test-rmse:6.27996
# [378]	train-rmse:1.92874	test-rmse:6.27776
# [379]	train-rmse:1.92687	test-rmse:6.28452
# [380]	train-rmse:1.92401	test-rmse:6.28731
# [381]	train-rmse:1.92043	test-rmse:6.28760
# [382]	train-rmse:1.91662	test-rmse:6.28405
# [383]	train-rmse:1.91360	test-rmse:6.28522
# [384]	train-rmse:1.91073	test-rmse:6.28246
# [385]	train-rmse:1.90812	test-rmse:6.28298
# [386]	train-rmse:1.90536	test-rmse:6.28087
# [387]	train-rmse:1.90205	test-rmse:6.27914
# [388]	train-rmse:1.89760	test-rmse:6.27610
# [389]	train-rmse:1.89380	test-rmse:6.27606
# [390]	train-rmse:1.89049	test-rmse:6.27351
# [391]	train-rmse:1.88692	test-rmse:6.27240
# [392]	train-rmse:1.88419	test-rmse:6.26966
# [393]	train-rmse:1.88065	test-rmse:6.27188
# [394]	train-rmse:1.87765	test-rmse:6.27021
# [395]	train-rmse:1.87572	test-rmse:6.27129
# [396]	train-rmse:1.87244	test-rmse:6.27197
# [397]	train-rmse:1.86964	test-rmse:6.27316
# [398]	train-rmse:1.86644	test-rmse:6.27399
# [399]	train-rmse:1.86469	test-rmse:6.27489
# [400]	train-rmse:1.86171	test-rmse:6.27156
# [401]	train-rmse:1.85929	test-rmse:6.27048
# RMSE of model on the  data set:   4.09
# MAE of XGB model on the  data set:   2.08
# MAPE of XGB model on the data set:    inf
# R2 of XGB model on the  data set:   0.93
# RMSE of model on the  data set:   2.01
# MAE of XGB model on the  data set:   1.03
# MAPE of XGB model on the data set:   4.27
# R2 of XGB model on the  data set:   0.98
# RMSE of model on the  data set:   6.26
# MAE of XGB model on the  data set:   3.70
# MAPE of XGB model on the data set:    inf
# R2 of XGB model on the  data set:   0.86
# RMSE of model on the  data set:   5.69
# MAE of XGB model on the  data set:   3.61
# MAPE of XGB model on the data set:    inf
# R2 of XGB model on the  data set:   0.87
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# divide by zero encountered in divide
# divide by zero encountered in divide
# divide by zero encountered in divide

# %%
import matplotlib.pyplot as plt

xx = np.linspace(0, 100, 10)
yy = xx

plt.figure()
plt.plot(xx, yy, c='k', linewidth=2)
plt.scatter(y_train, Z_train, marker='s')
plt.scatter(y_test, Z_test, marker='o')
plt.scatter(y_validation, Z_validation, marker='+')

plt.grid()
plt.legend(['y=x', 'Training set', 'Testing set','Validation set'], loc = 'upper left')
plt.tick_params (axis = 'both', which = 'major')
plt.axis('tight')
plt.xlabel('Tested fc(MPa)', fontsize=20)
plt.ylabel('Predicted fc(MPa)', fontsize=20)
plt.xlim([0, 95])
plt.ylim([0, 95])
plt.title('WOA', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
plt.savefig('WOA.svg',dpi=300,bbox_inches="tight")
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
data = pd.DataFrame({'x': y_train, 'y': Z_train})

lowess = sm.nonparametric.lowess
smoothed = lowess(Z_train, y_train, frac=0.2)
x_smooth = smoothed[:, 0]
y_smooth = smoothed[:, 1]

residuals = Z_train - np.interp(y_train, x_smooth, y_smooth)
std_error = np.std(residuals)
ci = 1.96 * std_error  # 95% 置信区间

# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(x_smooth, y_smooth, label='Smoothed Line', color='#00CED1')
plt.fill_between(x_smooth, y_smooth - ci, y_smooth + ci, color='#00CED1', alpha=0.2, label='95% Confidence Interval')
plt.scatter(y_train, Z_train, color='#00CED1', s=10, alpha=0.3, label='Data Points', marker='o')

# 设置图形标题和标签
plt.title('Line Plot with LOWESS Smoothing and Confidence Interval')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# 显示图形
plt.savefig('WOA1.svg',dpi=300,bbox_inches="tight")
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
data = pd.DataFrame({'x': y_test, 'y': Z_test})

lowess = sm.nonparametric.lowess
smoothed = lowess(Z_test, y_test, frac=0.2)
x_smooth = smoothed[:, 0]
y_smooth = smoothed[:, 1]

residuals = Z_test - np.interp(y_test, x_smooth, y_smooth)
std_error = np.std(residuals)
ci = 1.96 * std_error  # 95% 置信区间

# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(x_smooth, y_smooth, label='Smoothed Line', color='#DC143C')
plt.fill_between(x_smooth, y_smooth - ci, y_smooth + ci, color='#DC143C', alpha=0.2, label='95% Confidence Interval')
plt.scatter(y_test, Z_test, color='#DC143C', s=10, alpha=0.3, label='Data Points', marker='o')

# 设置图形标题和标签
plt.title('Line Plot with LOWESS Smoothing and Confidence Interval')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# 显示图形
plt.savefig('WOA2.svg',dpi=300,bbox_inches="tight")
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
data = pd.DataFrame({'x': y_validation, 'y': Z_validation})

lowess = sm.nonparametric.lowess
smoothed = lowess(Z_validation, y_validation, frac=0.2)
x_smooth = smoothed[:, 0]
y_smooth = smoothed[:, 1]

residuals = Z_validation - np.interp(y_validation, x_smooth, y_smooth)
std_error = np.std(residuals)
ci = 1.96 * std_error  # 95% 置信区间

# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(x_smooth, y_smooth, label='Smoothed Line', color='#FF8C00')
plt.fill_between(x_smooth, y_smooth - ci, y_smooth + ci, color='#FF8C00', alpha=0.2, label='95% Confidence Interval')
plt.scatter(y_validation, Z_validation, color='#FF8C00', s=10, alpha=0.3, label='Data Points', marker='o')

# 设置图形标题和标签
plt.title('Line Plot with LOWESS Smoothing and Confidence Interval')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# 显示图形
plt.savefig('WOA3.svg',dpi=300,bbox_inches="tight")
plt.show()
