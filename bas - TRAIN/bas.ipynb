# %%
import shap
import xgboost
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pylab as pl
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
# print the JS visualization code to the notebook
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# %run TunedXgboost.py
# Out:
# [0]	train-rmse:35.01745	test-rmse:35.82398
# [1]	train-rmse:30.07510	test-rmse:30.96510
# [2]	train-rmse:26.02378	test-rmse:26.97754
# [3]	train-rmse:22.66717	test-rmse:23.62958
# [4]	train-rmse:19.93028	test-rmse:20.95309
# [5]	train-rmse:17.68104	test-rmse:18.72458
# [6]	train-rmse:15.93843	test-rmse:17.07203
# [7]	train-rmse:14.53445	test-rmse:15.69388
# [8]	train-rmse:13.40296	test-rmse:14.58559
# [9]	train-rmse:12.58074	test-rmse:13.77276
# [10]	train-rmse:11.85351	test-rmse:13.05840
# [11]	train-rmse:11.32351	test-rmse:12.56952
# [12]	train-rmse:10.77834	test-rmse:12.04251
# [13]	train-rmse:10.39915	test-rmse:11.63535
# [14]	train-rmse:10.04570	test-rmse:11.29018
# [15]	train-rmse:9.78473	test-rmse:11.05770
# [16]	train-rmse:9.52318	test-rmse:10.79712
# [17]	train-rmse:9.35934	test-rmse:10.67987
# [18]	train-rmse:9.19734	test-rmse:10.51826
# [19]	train-rmse:9.01857	test-rmse:10.38612
# [20]	train-rmse:8.89834	test-rmse:10.25859
# [21]	train-rmse:8.72901	test-rmse:10.12035
# [22]	train-rmse:8.61356	test-rmse:10.04155
# [23]	train-rmse:8.47483	test-rmse:9.89288
# [24]	train-rmse:8.39485	test-rmse:9.80934
# [25]	train-rmse:8.26030	test-rmse:9.69400
# [26]	train-rmse:8.17198	test-rmse:9.64040
# [27]	train-rmse:8.08447	test-rmse:9.55537
# [28]	train-rmse:7.94998	test-rmse:9.46729
# [29]	train-rmse:7.86884	test-rmse:9.44047
# [30]	train-rmse:7.75491	test-rmse:9.29860
# [31]	train-rmse:7.63597	test-rmse:9.15949
# [32]	train-rmse:7.58265	test-rmse:9.13156
# [33]	train-rmse:7.53693	test-rmse:9.09941
# [34]	train-rmse:7.44064	test-rmse:9.05013
# [35]	train-rmse:7.33432	test-rmse:8.95464
# [36]	train-rmse:7.26577	test-rmse:8.92234
# [37]	train-rmse:7.22214	test-rmse:8.86164
# [38]	train-rmse:7.17640	test-rmse:8.83848
# [39]	train-rmse:7.11296	test-rmse:8.77356
# [40]	train-rmse:7.07823	test-rmse:8.76721
# [41]	train-rmse:7.02571	test-rmse:8.71589
# [42]	train-rmse:6.97976	test-rmse:8.65968
# [43]	train-rmse:6.91984	test-rmse:8.63235
# [44]	train-rmse:6.89977	test-rmse:8.61369
# [45]	train-rmse:6.86131	test-rmse:8.59048
# [46]	train-rmse:6.82177	test-rmse:8.56096
# [47]	train-rmse:6.79062	test-rmse:8.55369
# [48]	train-rmse:6.73572	test-rmse:8.54336
# [49]	train-rmse:6.71261	test-rmse:8.54396
# [50]	train-rmse:6.68441	test-rmse:8.52402
# [51]	train-rmse:6.64539	test-rmse:8.50005
# [52]	train-rmse:6.59901	test-rmse:8.45801
# [53]	train-rmse:6.55390	test-rmse:8.41640
# [54]	train-rmse:6.52638	test-rmse:8.38064
# [55]	train-rmse:6.47771	test-rmse:8.37714
# [56]	train-rmse:6.46172	test-rmse:8.34973
# [57]	train-rmse:6.43788	test-rmse:8.31866
# [58]	train-rmse:6.37804	test-rmse:8.28557
# [59]	train-rmse:6.35426	test-rmse:8.26632
# [60]	train-rmse:6.33520	test-rmse:8.28635
# [61]	train-rmse:6.31588	test-rmse:8.24557
# [62]	train-rmse:6.29642	test-rmse:8.23516
# [63]	train-rmse:6.27448	test-rmse:8.22071
# [64]	train-rmse:6.24474	test-rmse:8.20961
# [65]	train-rmse:6.21550	test-rmse:8.19649
# [66]	train-rmse:6.18041	test-rmse:8.17045
# [67]	train-rmse:6.13110	test-rmse:8.13123
# [68]	train-rmse:6.11849	test-rmse:8.12410
# [69]	train-rmse:6.09186	test-rmse:8.11581
# [70]	train-rmse:6.07911	test-rmse:8.11564
# [71]	train-rmse:6.04303	test-rmse:8.07469
# [72]	train-rmse:6.02174	test-rmse:8.05501
# [73]	train-rmse:5.98808	test-rmse:8.04565
# [74]	train-rmse:5.96801	test-rmse:8.03077
# [75]	train-rmse:5.94011	test-rmse:8.00130
# [76]	train-rmse:5.91183	test-rmse:8.00408
# [77]	train-rmse:5.88660	test-rmse:7.99610
# [78]	train-rmse:5.85487	test-rmse:7.98118
# [79]	train-rmse:5.84040	test-rmse:7.96365
# [80]	train-rmse:5.81558	test-rmse:7.94215
# [81]	train-rmse:5.78874	test-rmse:7.92958
# [82]	train-rmse:5.76872	test-rmse:7.91971
# [83]	train-rmse:5.73732	test-rmse:7.88589
# [84]	train-rmse:5.71495	test-rmse:7.87003
# [85]	train-rmse:5.68259	test-rmse:7.83982
# [86]	train-rmse:5.65412	test-rmse:7.83534
# [87]	train-rmse:5.63539	test-rmse:7.82804
# [88]	train-rmse:5.61466	test-rmse:7.81739
# [89]	train-rmse:5.58866	test-rmse:7.80150
# [90]	train-rmse:5.57512	test-rmse:7.79567
# [91]	train-rmse:5.54355	test-rmse:7.77367
# [92]	train-rmse:5.52459	test-rmse:7.77848
# [93]	train-rmse:5.49031	test-rmse:7.75121
# [94]	train-rmse:5.46293	test-rmse:7.75097
# [95]	train-rmse:5.44180	test-rmse:7.73841
# [96]	train-rmse:5.40626	test-rmse:7.73302
# [97]	train-rmse:5.38691	test-rmse:7.71236
# [98]	train-rmse:5.37335	test-rmse:7.70453
# [99]	train-rmse:5.36717	test-rmse:7.69730
# [100]	train-rmse:5.34603	test-rmse:7.66987
# [101]	train-rmse:5.32654	test-rmse:7.65589
# [102]	train-rmse:5.31623	test-rmse:7.64314
# [103]	train-rmse:5.29119	test-rmse:7.61192
# [104]	train-rmse:5.26231	test-rmse:7.59593
# [105]	train-rmse:5.24532	test-rmse:7.58771
# [106]	train-rmse:5.22101	test-rmse:7.57335
# [107]	train-rmse:5.20634	test-rmse:7.58203
# [108]	train-rmse:5.17248	test-rmse:7.57734
# [109]	train-rmse:5.15274	test-rmse:7.55721
# [110]	train-rmse:5.14386	test-rmse:7.54202
# [111]	train-rmse:5.12347	test-rmse:7.52439
# [112]	train-rmse:5.11420	test-rmse:7.52342
# [113]	train-rmse:5.09932	test-rmse:7.51664
# [114]	train-rmse:5.08772	test-rmse:7.50112
# [115]	train-rmse:5.06944	test-rmse:7.50532
# [116]	train-rmse:5.04904	test-rmse:7.48527
# [117]	train-rmse:5.02692	test-rmse:7.47628
# [118]	train-rmse:5.00970	test-rmse:7.46323
# [119]	train-rmse:4.97931	test-rmse:7.44674
# [120]	train-rmse:4.96265	test-rmse:7.44447
# [121]	train-rmse:4.93429	test-rmse:7.43512
# [122]	train-rmse:4.91934	test-rmse:7.43322
# [123]	train-rmse:4.90059	test-rmse:7.41407
# [124]	train-rmse:4.88347	test-rmse:7.40235
# [125]	train-rmse:4.87170	test-rmse:7.39116
# [126]	train-rmse:4.86255	test-rmse:7.39877
# [127]	train-rmse:4.84475	test-rmse:7.39266
# [128]	train-rmse:4.82847	test-rmse:7.37158
# [129]	train-rmse:4.82250	test-rmse:7.37062
# [130]	train-rmse:4.80684	test-rmse:7.36223
# [131]	train-rmse:4.79463	test-rmse:7.37378
# [132]	train-rmse:4.78819	test-rmse:7.38453
# [133]	train-rmse:4.77695	test-rmse:7.38346
# [134]	train-rmse:4.76305	test-rmse:7.37454
# [135]	train-rmse:4.75559	test-rmse:7.38284
# [136]	train-rmse:4.74829	test-rmse:7.39178
# [137]	train-rmse:4.73467	test-rmse:7.37266
# [138]	train-rmse:4.71749	test-rmse:7.36405
# [139]	train-rmse:4.70715	test-rmse:7.35108
# [140]	train-rmse:4.69054	test-rmse:7.34040
# [141]	train-rmse:4.68466	test-rmse:7.34023
# [142]	train-rmse:4.66298	test-rmse:7.32986
# [143]	train-rmse:4.65293	test-rmse:7.31951
# [144]	train-rmse:4.63652	test-rmse:7.32111
# [145]	train-rmse:4.62053	test-rmse:7.31871
# [146]	train-rmse:4.60463	test-rmse:7.30940
# [147]	train-rmse:4.58785	test-rmse:7.30031
# [148]	train-rmse:4.57943	test-rmse:7.31405
# [149]	train-rmse:4.56728	test-rmse:7.30950
# [150]	train-rmse:4.55191	test-rmse:7.33197
# [151]	train-rmse:4.54308	test-rmse:7.32715
# [152]	train-rmse:4.53059	test-rmse:7.31703
# [153]	train-rmse:4.52291	test-rmse:7.32390
# [154]	train-rmse:4.50466	test-rmse:7.31170
# [155]	train-rmse:4.49576	test-rmse:7.31075
# [156]	train-rmse:4.48623	test-rmse:7.30745
# [157]	train-rmse:4.47020	test-rmse:7.32108
# [158]	train-rmse:4.45841	test-rmse:7.30884
# [159]	train-rmse:4.44366	test-rmse:7.33407
# [160]	train-rmse:4.42983	test-rmse:7.32317
# [161]	train-rmse:4.42533	test-rmse:7.32194
# [162]	train-rmse:4.41349	test-rmse:7.31387
# [163]	train-rmse:4.40504	test-rmse:7.30570
# [164]	train-rmse:4.39677	test-rmse:7.28966
# [165]	train-rmse:4.38191	test-rmse:7.27754
# [166]	train-rmse:4.37658	test-rmse:7.27459
# [167]	train-rmse:4.36654	test-rmse:7.27226
# [168]	train-rmse:4.35696	test-rmse:7.27722
# [169]	train-rmse:4.34775	test-rmse:7.27364
# [170]	train-rmse:4.33753	test-rmse:7.26355
# [171]	train-rmse:4.32833	test-rmse:7.26059
# [172]	train-rmse:4.32228	test-rmse:7.25775
# [173]	train-rmse:4.31474	test-rmse:7.23856
# [174]	train-rmse:4.30668	test-rmse:7.23947
# [175]	train-rmse:4.29766	test-rmse:7.21523
# [176]	train-rmse:4.28732	test-rmse:7.21126
# [177]	train-rmse:4.27878	test-rmse:7.20444
# [178]	train-rmse:4.26517	test-rmse:7.20624
# [179]	train-rmse:4.25980	test-rmse:7.20845
# [180]	train-rmse:4.25460	test-rmse:7.20204
# [181]	train-rmse:4.24952	test-rmse:7.19283
# [182]	train-rmse:4.23491	test-rmse:7.18863
# [183]	train-rmse:4.22903	test-rmse:7.17777
# [184]	train-rmse:4.20995	test-rmse:7.18807
# [185]	train-rmse:4.20367	test-rmse:7.19604
# [186]	train-rmse:4.19301	test-rmse:7.19266
# [187]	train-rmse:4.18428	test-rmse:7.18255
# [188]	train-rmse:4.17750	test-rmse:7.17111
# [189]	train-rmse:4.17016	test-rmse:7.18294
# [190]	train-rmse:4.15627	test-rmse:7.16742
# [191]	train-rmse:4.14788	test-rmse:7.17375
# [192]	train-rmse:4.13956	test-rmse:7.16878
# [193]	train-rmse:4.13494	test-rmse:7.16593
# [194]	train-rmse:4.12730	test-rmse:7.16181
# [195]	train-rmse:4.11880	test-rmse:7.15410
# [196]	train-rmse:4.10734	test-rmse:7.13880
# [197]	train-rmse:4.09480	test-rmse:7.13966
# [198]	train-rmse:4.08254	test-rmse:7.12730
# [199]	train-rmse:4.07483	test-rmse:7.13119
# [200]	train-rmse:4.06081	test-rmse:7.12753
# [201]	train-rmse:4.05371	test-rmse:7.11651
# [202]	train-rmse:4.04109	test-rmse:7.11682
# [203]	train-rmse:4.02349	test-rmse:7.11190
# [204]	train-rmse:4.01702	test-rmse:7.09788
# [205]	train-rmse:4.00872	test-rmse:7.09836
# [206]	train-rmse:3.99924	test-rmse:7.09861
# [207]	train-rmse:3.99438	test-rmse:7.08652
# [208]	train-rmse:3.98915	test-rmse:7.08792
# [209]	train-rmse:3.98035	test-rmse:7.08329
# [210]	train-rmse:3.97774	test-rmse:7.07411
# [211]	train-rmse:3.97285	test-rmse:7.08313
# [212]	train-rmse:3.95775	test-rmse:7.07846
# [213]	train-rmse:3.94998	test-rmse:7.08022
# [214]	train-rmse:3.94428	test-rmse:7.08072
# [215]	train-rmse:3.93281	test-rmse:7.08810
# [216]	train-rmse:3.92856	test-rmse:7.09172
# [217]	train-rmse:3.91993	test-rmse:7.10255
# [218]	train-rmse:3.90323	test-rmse:7.09424
# [219]	train-rmse:3.89409	test-rmse:7.08944
# [220]	train-rmse:3.88920	test-rmse:7.09037
# [221]	train-rmse:3.87889	test-rmse:7.08103
# [222]	train-rmse:3.87157	test-rmse:7.09038
# [223]	train-rmse:3.86605	test-rmse:7.09503
# [224]	train-rmse:3.86089	test-rmse:7.10374
# [225]	train-rmse:3.85112	test-rmse:7.09064
# [226]	train-rmse:3.84446	test-rmse:7.08482
# [227]	train-rmse:3.83336	test-rmse:7.08061
# [228]	train-rmse:3.82355	test-rmse:7.07234
# [229]	train-rmse:3.82065	test-rmse:7.06626
# [230]	train-rmse:3.81373	test-rmse:7.06128
# [231]	train-rmse:3.80518	test-rmse:7.06422
# [232]	train-rmse:3.79553	test-rmse:7.06115
# [233]	train-rmse:3.78977	test-rmse:7.05951
# [234]	train-rmse:3.77611	test-rmse:7.04351
# [235]	train-rmse:3.76741	test-rmse:7.03394
# [236]	train-rmse:3.76157	test-rmse:7.03343
# [237]	train-rmse:3.75629	test-rmse:7.03545
# [238]	train-rmse:3.74912	test-rmse:7.03134
# [239]	train-rmse:3.74360	test-rmse:7.02347
# [240]	train-rmse:3.73557	test-rmse:7.00823
# [241]	train-rmse:3.73179	test-rmse:7.00420
# [242]	train-rmse:3.72982	test-rmse:7.00050
# [243]	train-rmse:3.71731	test-rmse:6.98055
# [244]	train-rmse:3.70643	test-rmse:6.98129
# [245]	train-rmse:3.70476	test-rmse:6.97690
# [246]	train-rmse:3.69725	test-rmse:6.96944
# [247]	train-rmse:3.68854	test-rmse:6.96666
# [248]	train-rmse:3.68003	test-rmse:6.97348
# [249]	train-rmse:3.67686	test-rmse:6.97160
# [250]	train-rmse:3.66468	test-rmse:6.96121
# [251]	train-rmse:3.66045	test-rmse:6.97286
# [252]	train-rmse:3.65525	test-rmse:6.96986
# [253]	train-rmse:3.64933	test-rmse:6.96651
# [254]	train-rmse:3.64324	test-rmse:6.97212
# [255]	train-rmse:3.63880	test-rmse:6.97110
# [256]	train-rmse:3.63272	test-rmse:6.97140
# [257]	train-rmse:3.62902	test-rmse:6.98287
# [258]	train-rmse:3.62331	test-rmse:6.98363
# [259]	train-rmse:3.62082	test-rmse:6.97799
# [260]	train-rmse:3.61459	test-rmse:6.97384
# [261]	train-rmse:3.61017	test-rmse:6.97072
# [262]	train-rmse:3.60174	test-rmse:6.97235
# [263]	train-rmse:3.59784	test-rmse:6.96193
# [264]	train-rmse:3.59389	test-rmse:6.94874
# [265]	train-rmse:3.58214	test-rmse:6.94018
# [266]	train-rmse:3.57812	test-rmse:6.94241
# [267]	train-rmse:3.57240	test-rmse:6.93872
# [268]	train-rmse:3.56669	test-rmse:6.93893
# [269]	train-rmse:3.56300	test-rmse:6.93614
# [270]	train-rmse:3.55722	test-rmse:6.93836
# [271]	train-rmse:3.55151	test-rmse:6.93968
# [272]	train-rmse:3.54351	test-rmse:6.94054
# [273]	train-rmse:3.54115	test-rmse:6.94053
# [274]	train-rmse:3.53262	test-rmse:6.93678
# [275]	train-rmse:3.53017	test-rmse:6.93077
# [276]	train-rmse:3.52131	test-rmse:6.93728
# [277]	train-rmse:3.51263	test-rmse:6.92170
# [278]	train-rmse:3.50574	test-rmse:6.93081
# [279]	train-rmse:3.49499	test-rmse:6.93461
# [280]	train-rmse:3.49257	test-rmse:6.93277
# [281]	train-rmse:3.48904	test-rmse:6.92672
# [282]	train-rmse:3.48333	test-rmse:6.92482
# [283]	train-rmse:3.47961	test-rmse:6.92565
# [284]	train-rmse:3.47590	test-rmse:6.92654
# [285]	train-rmse:3.47243	test-rmse:6.92641
# [286]	train-rmse:3.47215	test-rmse:6.92391
# [287]	train-rmse:3.46770	test-rmse:6.91860
# [288]	train-rmse:3.46108	test-rmse:6.91728
# [289]	train-rmse:3.45603	test-rmse:6.90762
# [290]	train-rmse:3.45119	test-rmse:6.90515
# [291]	train-rmse:3.44539	test-rmse:6.89804
# [292]	train-rmse:3.43647	test-rmse:6.89054
# [293]	train-rmse:3.43436	test-rmse:6.88763
# [294]	train-rmse:3.42831	test-rmse:6.89768
# [295]	train-rmse:3.42014	test-rmse:6.89469
# [296]	train-rmse:3.41665	test-rmse:6.88723
# [297]	train-rmse:3.41336	test-rmse:6.88525
# [298]	train-rmse:3.40539	test-rmse:6.87831
# [299]	train-rmse:3.39437	test-rmse:6.87216
# [300]	train-rmse:3.38988	test-rmse:6.88087
# [301]	train-rmse:3.38294	test-rmse:6.88009
# [302]	train-rmse:3.37655	test-rmse:6.86893
# [303]	train-rmse:3.37389	test-rmse:6.86682
# [304]	train-rmse:3.37183	test-rmse:6.87359
# [305]	train-rmse:3.36550	test-rmse:6.86905
# [306]	train-rmse:3.36282	test-rmse:6.86721
# [307]	train-rmse:3.35989	test-rmse:6.87481
# [308]	train-rmse:3.35418	test-rmse:6.87042
# [309]	train-rmse:3.34959	test-rmse:6.86156
# [310]	train-rmse:3.34460	test-rmse:6.86415
# [311]	train-rmse:3.34144	test-rmse:6.85605
# [312]	train-rmse:3.33816	test-rmse:6.85533
# [313]	train-rmse:3.33348	test-rmse:6.85218
# [314]	train-rmse:3.32576	test-rmse:6.85192
# [315]	train-rmse:3.32387	test-rmse:6.85541
# [316]	train-rmse:3.32106	test-rmse:6.85792
# [317]	train-rmse:3.31860	test-rmse:6.85881
# [318]	train-rmse:3.31485	test-rmse:6.85293
# [319]	train-rmse:3.30712	test-rmse:6.84735
# [320]	train-rmse:3.30264	test-rmse:6.85387
# [321]	train-rmse:3.29895	test-rmse:6.85864
# [322]	train-rmse:3.29145	test-rmse:6.85280
# [323]	train-rmse:3.28726	test-rmse:6.85170
# [324]	train-rmse:3.28190	test-rmse:6.85486
# [325]	train-rmse:3.27854	test-rmse:6.85184
# [326]	train-rmse:3.27373	test-rmse:6.84862
# [327]	train-rmse:3.27088	test-rmse:6.84835
# [328]	train-rmse:3.26546	test-rmse:6.85035
# [329]	train-rmse:3.26279	test-rmse:6.84208
# [330]	train-rmse:3.26090	test-rmse:6.84543
# [331]	train-rmse:3.25596	test-rmse:6.84006
# [332]	train-rmse:3.25344	test-rmse:6.84115
# [333]	train-rmse:3.24533	test-rmse:6.83836
# [334]	train-rmse:3.23033	test-rmse:6.84417
# [335]	train-rmse:3.22557	test-rmse:6.83688
# [336]	train-rmse:3.21988	test-rmse:6.82204
# [337]	train-rmse:3.21617	test-rmse:6.81917
# [338]	train-rmse:3.21280	test-rmse:6.81882
# [339]	train-rmse:3.20765	test-rmse:6.81809
# [340]	train-rmse:3.20032	test-rmse:6.80200
# [341]	train-rmse:3.19469	test-rmse:6.80425
# [342]	train-rmse:3.19115	test-rmse:6.80697
# [343]	train-rmse:3.18472	test-rmse:6.80854
# [344]	train-rmse:3.18249	test-rmse:6.80765
# [345]	train-rmse:3.17940	test-rmse:6.80489
# [346]	train-rmse:3.17822	test-rmse:6.80343
# [347]	train-rmse:3.17318	test-rmse:6.79360
# [348]	train-rmse:3.16790	test-rmse:6.79314
# [349]	train-rmse:3.16161	test-rmse:6.78795
# [350]	train-rmse:3.15904	test-rmse:6.78506
# [351]	train-rmse:3.15211	test-rmse:6.78855
# [352]	train-rmse:3.14869	test-rmse:6.79049
# [353]	train-rmse:3.14460	test-rmse:6.78659
# [354]	train-rmse:3.13917	test-rmse:6.78890
# [355]	train-rmse:3.13250	test-rmse:6.79257
# [356]	train-rmse:3.12844	test-rmse:6.79078
# [357]	train-rmse:3.12830	test-rmse:6.78069
# [358]	train-rmse:3.12114	test-rmse:6.79122
# [359]	train-rmse:3.11858	test-rmse:6.79602
# [360]	train-rmse:3.11366	test-rmse:6.78998
# [361]	train-rmse:3.10977	test-rmse:6.79044
# [362]	train-rmse:3.10766	test-rmse:6.79672
# [363]	train-rmse:3.10529	test-rmse:6.79372
# [364]	train-rmse:3.09967	test-rmse:6.78638
# [365]	train-rmse:3.09591	test-rmse:6.77859
# [366]	train-rmse:3.09122	test-rmse:6.78203
# [367]	train-rmse:3.08817	test-rmse:6.78994
# [368]	train-rmse:3.08273	test-rmse:6.78797
# [369]	train-rmse:3.07934	test-rmse:6.78434
# [370]	train-rmse:3.07651	test-rmse:6.79034
# [371]	train-rmse:3.06963	test-rmse:6.78383
# [372]	train-rmse:3.06616	test-rmse:6.78730
# [373]	train-rmse:3.06368	test-rmse:6.78835
# [374]	train-rmse:3.05774	test-rmse:6.78429
# [375]	train-rmse:3.05309	test-rmse:6.78562
# [376]	train-rmse:3.05181	test-rmse:6.78206
# [377]	train-rmse:3.04737	test-rmse:6.77923
# [378]	train-rmse:3.04340	test-rmse:6.77890
# [379]	train-rmse:3.03931	test-rmse:6.78225
# [380]	train-rmse:3.03654	test-rmse:6.78576
# [381]	train-rmse:3.03334	test-rmse:6.79299
# [382]	train-rmse:3.02796	test-rmse:6.79243
# [383]	train-rmse:3.02454	test-rmse:6.79284
# [384]	train-rmse:3.02151	test-rmse:6.78955
# [385]	train-rmse:3.01886	test-rmse:6.79165
# [386]	train-rmse:3.01213	test-rmse:6.78536
# [387]	train-rmse:3.01055	test-rmse:6.78503
# [388]	train-rmse:3.00858	test-rmse:6.77878
# [389]	train-rmse:3.00607	test-rmse:6.77621
# [390]	train-rmse:3.00311	test-rmse:6.77609
# [391]	train-rmse:2.99964	test-rmse:6.76817
# [392]	train-rmse:2.99428	test-rmse:6.77151
# [393]	train-rmse:2.98954	test-rmse:6.78461
# [394]	train-rmse:2.98555	test-rmse:6.78321
# [395]	train-rmse:2.98362	test-rmse:6.78053
# [396]	train-rmse:2.97648	test-rmse:6.78533
# [397]	train-rmse:2.97480	test-rmse:6.78820
# [398]	train-rmse:2.97318	test-rmse:6.78419
# [399]	train-rmse:2.97011	test-rmse:6.78471
# [400]	train-rmse:2.97104	test-rmse:6.78963
# [401]	train-rmse:2.96468	test-rmse:6.79651
# [402]	train-rmse:2.96392	test-rmse:6.79251
# [403]	train-rmse:2.95982	test-rmse:6.79738
# [404]	train-rmse:2.95809	test-rmse:6.79886
# [405]	train-rmse:2.95513	test-rmse:6.79417
# [406]	train-rmse:2.95146	test-rmse:6.79435
# [407]	train-rmse:2.94882	test-rmse:6.78148
# [408]	train-rmse:2.94472	test-rmse:6.78078
# [409]	train-rmse:2.94032	test-rmse:6.77912
# [410]	train-rmse:2.93812	test-rmse:6.77993
# [411]	train-rmse:2.93687	test-rmse:6.78258
# [412]	train-rmse:2.93158	test-rmse:6.78023
# [413]	train-rmse:2.92720	test-rmse:6.77850
# [414]	train-rmse:2.92547	test-rmse:6.77713
# [415]	train-rmse:2.92130	test-rmse:6.76838
# [416]	train-rmse:2.91656	test-rmse:6.76796
# [417]	train-rmse:2.91504	test-rmse:6.77245
# [418]	train-rmse:2.91104	test-rmse:6.77168
# [419]	train-rmse:2.90749	test-rmse:6.76924
# [420]	train-rmse:2.90471	test-rmse:6.76550
# [421]	train-rmse:2.90370	test-rmse:6.76342
# [422]	train-rmse:2.89996	test-rmse:6.75688
# [423]	train-rmse:2.89601	test-rmse:6.76089
# [424]	train-rmse:2.89149	test-rmse:6.75674
# [425]	train-rmse:2.88723	test-rmse:6.75217
# [426]	train-rmse:2.88603	test-rmse:6.74888
# [427]	train-rmse:2.88265	test-rmse:6.75341
# [428]	train-rmse:2.88103	test-rmse:6.75085
# [429]	train-rmse:2.87651	test-rmse:6.74882
# [430]	train-rmse:2.87384	test-rmse:6.74549
# [431]	train-rmse:2.86954	test-rmse:6.74583
# [432]	train-rmse:2.86506	test-rmse:6.74979
# [433]	train-rmse:2.86426	test-rmse:6.75180
# [434]	train-rmse:2.85677	test-rmse:6.75085
# [435]	train-rmse:2.85563	test-rmse:6.74687
# [436]	train-rmse:2.85338	test-rmse:6.74423
# [437]	train-rmse:2.85011	test-rmse:6.74438
# [438]	train-rmse:2.84678	test-rmse:6.74610
# [439]	train-rmse:2.84417	test-rmse:6.74354
# [440]	train-rmse:2.84130	test-rmse:6.73897
# [441]	train-rmse:2.83989	test-rmse:6.73733
# [442]	train-rmse:2.83669	test-rmse:6.72726
# [443]	train-rmse:2.83571	test-rmse:6.73288
# [444]	train-rmse:2.83450	test-rmse:6.73625
# [445]	train-rmse:2.83303	test-rmse:6.73704
# [446]	train-rmse:2.83219	test-rmse:6.74570
# [447]	train-rmse:2.82822	test-rmse:6.74781
# [448]	train-rmse:2.82316	test-rmse:6.73784
# [449]	train-rmse:2.81904	test-rmse:6.73351
# [450]	train-rmse:2.81771	test-rmse:6.73299
# [451]	train-rmse:2.81293	test-rmse:6.72196
# [452]	train-rmse:2.81020	test-rmse:6.72156
# [453]	train-rmse:2.80740	test-rmse:6.73861
# [454]	train-rmse:2.80461	test-rmse:6.74770
# [455]	train-rmse:2.80235	test-rmse:6.74301
# [456]	train-rmse:2.79997	test-rmse:6.74720
# [457]	train-rmse:2.79488	test-rmse:6.73832
# [458]	train-rmse:2.79339	test-rmse:6.73353
# [459]	train-rmse:2.79075	test-rmse:6.73820
# [460]	train-rmse:2.78829	test-rmse:6.73342
# [461]	train-rmse:2.78562	test-rmse:6.73035
# [462]	train-rmse:2.78248	test-rmse:6.73612
# [463]	train-rmse:2.78143	test-rmse:6.73322
# [464]	train-rmse:2.77733	test-rmse:6.72848
# [465]	train-rmse:2.77719	test-rmse:6.73414
# [466]	train-rmse:2.77506	test-rmse:6.73581
# [467]	train-rmse:2.77235	test-rmse:6.73679
# [468]	train-rmse:2.76988	test-rmse:6.74134
# [469]	train-rmse:2.76929	test-rmse:6.73572
# [470]	train-rmse:2.76711	test-rmse:6.73483
# [471]	train-rmse:2.76287	test-rmse:6.73079
# [472]	train-rmse:2.76240	test-rmse:6.73721
# [473]	train-rmse:2.75608	test-rmse:6.73538
# [474]	train-rmse:2.75508	test-rmse:6.73039
# [475]	train-rmse:2.75254	test-rmse:6.73224
# [476]	train-rmse:2.74822	test-rmse:6.72663
# [477]	train-rmse:2.74280	test-rmse:6.72436
# [478]	train-rmse:2.74013	test-rmse:6.72190
# [479]	train-rmse:2.73663	test-rmse:6.72072
# [480]	train-rmse:2.73308	test-rmse:6.71669
# [481]	train-rmse:2.72964	test-rmse:6.71532
# [482]	train-rmse:2.72742	test-rmse:6.71792
# [483]	train-rmse:2.72377	test-rmse:6.71282
# [484]	train-rmse:2.72117	test-rmse:6.71354
# [485]	train-rmse:2.71999	test-rmse:6.71210
# [486]	train-rmse:2.71758	test-rmse:6.71036
# [487]	train-rmse:2.71382	test-rmse:6.70476
# [488]	train-rmse:2.71091	test-rmse:6.70401
# [489]	train-rmse:2.70819	test-rmse:6.70831
# [490]	train-rmse:2.70647	test-rmse:6.70206
# [491]	train-rmse:2.70550	test-rmse:6.70350
# [492]	train-rmse:2.70308	test-rmse:6.69995
# [493]	train-rmse:2.70278	test-rmse:6.70124
# [494]	train-rmse:2.70054	test-rmse:6.70098
# [495]	train-rmse:2.69717	test-rmse:6.69916
# [496]	train-rmse:2.69480	test-rmse:6.69526
# [497]	train-rmse:2.69369	test-rmse:6.69877
# [498]	train-rmse:2.69069	test-rmse:6.69320
# [499]	train-rmse:2.69052	test-rmse:6.70291
# [500]	train-rmse:2.68640	test-rmse:6.70422
# [501]	train-rmse:2.68494	test-rmse:6.69805
# [502]	train-rmse:2.67942	test-rmse:6.69794
# [503]	train-rmse:2.67438	test-rmse:6.69277
# [504]	train-rmse:2.66930	test-rmse:6.68997
# [505]	train-rmse:2.66737	test-rmse:6.68708
# [506]	train-rmse:2.66538	test-rmse:6.69054
# [507]	train-rmse:2.66226	test-rmse:6.68903
# [508]	train-rmse:2.66005	test-rmse:6.68373
# [509]	train-rmse:2.65852	test-rmse:6.68235
# [510]	train-rmse:2.65510	test-rmse:6.68692
# [511]	train-rmse:2.65145	test-rmse:6.68599
# [512]	train-rmse:2.64754	test-rmse:6.68108
# [513]	train-rmse:2.64608	test-rmse:6.68420
# [514]	train-rmse:2.64445	test-rmse:6.68915
# [515]	train-rmse:2.64202	test-rmse:6.68828
# [516]	train-rmse:2.63720	test-rmse:6.68870
# [517]	train-rmse:2.63556	test-rmse:6.68578
# [518]	train-rmse:2.63063	test-rmse:6.68984
# [519]	train-rmse:2.62935	test-rmse:6.68587
# [520]	train-rmse:2.62788	test-rmse:6.69044
# [521]	train-rmse:2.62495	test-rmse:6.69424
# [522]	train-rmse:2.62373	test-rmse:6.68818
# [523]	train-rmse:2.62153	test-rmse:6.68536
# [524]	train-rmse:2.61874	test-rmse:6.68245
# [525]	train-rmse:2.61476	test-rmse:6.67970
# [526]	train-rmse:2.60984	test-rmse:6.68629
# [527]	train-rmse:2.60669	test-rmse:6.68893
# [528]	train-rmse:2.60437	test-rmse:6.68105
# [529]	train-rmse:2.60067	test-rmse:6.68565
# [530]	train-rmse:2.59788	test-rmse:6.69306
# [531]	train-rmse:2.59773	test-rmse:6.68570
# [532]	train-rmse:2.59290	test-rmse:6.68537
# [533]	train-rmse:2.59087	test-rmse:6.68455
# [534]	train-rmse:2.58879	test-rmse:6.68845
# [535]	train-rmse:2.58520	test-rmse:6.69473
# [536]	train-rmse:2.58403	test-rmse:6.69341
# [537]	train-rmse:2.58078	test-rmse:6.68845
# [538]	train-rmse:2.57979	test-rmse:6.69152
# [539]	train-rmse:2.57869	test-rmse:6.69185
# [540]	train-rmse:2.57691	test-rmse:6.68910
# [541]	train-rmse:2.57538	test-rmse:6.68652
# [542]	train-rmse:2.57409	test-rmse:6.68715
# [543]	train-rmse:2.57390	test-rmse:6.68470
# [544]	train-rmse:2.57175	test-rmse:6.68185
# [545]	train-rmse:2.57126	test-rmse:6.67749
# [546]	train-rmse:2.56976	test-rmse:6.67874
# [547]	train-rmse:2.56850	test-rmse:6.68435
# [548]	train-rmse:2.56579	test-rmse:6.68262
# [549]	train-rmse:2.56291	test-rmse:6.68152
# [550]	train-rmse:2.56232	test-rmse:6.68200
# [551]	train-rmse:2.56109	test-rmse:6.68283
# [552]	train-rmse:2.55747	test-rmse:6.68616
# [553]	train-rmse:2.55520	test-rmse:6.69000
# [554]	train-rmse:2.55257	test-rmse:6.68268
# [555]	train-rmse:2.55198	test-rmse:6.68428
# [556]	train-rmse:2.54966	test-rmse:6.68175
# [557]	train-rmse:2.54810	test-rmse:6.68633
# [558]	train-rmse:2.54418	test-rmse:6.68242
# [559]	train-rmse:2.53891	test-rmse:6.68603
# [560]	train-rmse:2.53737	test-rmse:6.68488
# [561]	train-rmse:2.53577	test-rmse:6.67599
# [562]	train-rmse:2.53307	test-rmse:6.67641
# [563]	train-rmse:2.53028	test-rmse:6.68031
# [564]	train-rmse:2.52844	test-rmse:6.67762
# [565]	train-rmse:2.52462	test-rmse:6.67874
# [566]	train-rmse:2.52282	test-rmse:6.67488
# [567]	train-rmse:2.51779	test-rmse:6.66989
# [568]	train-rmse:2.51723	test-rmse:6.67156
# [569]	train-rmse:2.51714	test-rmse:6.66784
# [570]	train-rmse:2.51465	test-rmse:6.66643
# [571]	train-rmse:2.51319	test-rmse:6.66637
# [572]	train-rmse:2.51245	test-rmse:6.66813
# [573]	train-rmse:2.51087	test-rmse:6.67140
# [574]	train-rmse:2.50916	test-rmse:6.67247
# [575]	train-rmse:2.50460	test-rmse:6.67034
# [576]	train-rmse:2.50029	test-rmse:6.67056
# [577]	train-rmse:2.49878	test-rmse:6.67100
# [578]	train-rmse:2.49746	test-rmse:6.67323
# [579]	train-rmse:2.49570	test-rmse:6.66942
# [580]	train-rmse:2.49504	test-rmse:6.67207
# [581]	train-rmse:2.49395	test-rmse:6.66966
# [582]	train-rmse:2.49184	test-rmse:6.67357
# [583]	train-rmse:2.48842	test-rmse:6.66961
# [584]	train-rmse:2.48600	test-rmse:6.67220
# [585]	train-rmse:2.48145	test-rmse:6.67553
# [586]	train-rmse:2.48105	test-rmse:6.67372
# [587]	train-rmse:2.48076	test-rmse:6.67621
# [588]	train-rmse:2.47832	test-rmse:6.67136
# [589]	train-rmse:2.47592	test-rmse:6.67185
# [590]	train-rmse:2.47339	test-rmse:6.67779
# [591]	train-rmse:2.47013	test-rmse:6.67996
# [592]	train-rmse:2.46685	test-rmse:6.67944
# [593]	train-rmse:2.46438	test-rmse:6.67907
# [594]	train-rmse:2.46245	test-rmse:6.67823
# [595]	train-rmse:2.46152	test-rmse:6.67509
# [596]	train-rmse:2.46015	test-rmse:6.67311
# [597]	train-rmse:2.45667	test-rmse:6.67848
# [598]	train-rmse:2.45587	test-rmse:6.67988
# [599]	train-rmse:2.45423	test-rmse:6.68320
# [600]	train-rmse:2.45215	test-rmse:6.68286
# [601]	train-rmse:2.45039	test-rmse:6.68027
# [602]	train-rmse:2.44865	test-rmse:6.69094
# [603]	train-rmse:2.44790	test-rmse:6.69316
# [604]	train-rmse:2.44463	test-rmse:6.69659
# [605]	train-rmse:2.44365	test-rmse:6.69464
# [606]	train-rmse:2.44415	test-rmse:6.69102
# [607]	train-rmse:2.44309	test-rmse:6.68776
# [608]	train-rmse:2.44194	test-rmse:6.68596
# [609]	train-rmse:2.44029	test-rmse:6.67991
# [610]	train-rmse:2.43989	test-rmse:6.67999
# [611]	train-rmse:2.43765	test-rmse:6.67360
# [612]	train-rmse:2.43584	test-rmse:6.67308
# [613]	train-rmse:2.43305	test-rmse:6.67845
# [614]	train-rmse:2.43120	test-rmse:6.67904
# [615]	train-rmse:2.42669	test-rmse:6.67990
# [616]	train-rmse:2.42528	test-rmse:6.68107
# [617]	train-rmse:2.42329	test-rmse:6.68080
# [618]	train-rmse:2.42146	test-rmse:6.68332
# [619]	train-rmse:2.41893	test-rmse:6.68109
# [620]	train-rmse:2.41621	test-rmse:6.67735
# [621]	train-rmse:2.41345	test-rmse:6.67893
# RMSE of model on the  data set:   4.39
# MAE of XGB model on the  data set:   2.66
# MAPE of XGB model on the data set:    inf
# R2 of XGB model on the  data set:   0.92
# RMSE of model on the  data set:   2.51
# MAE of XGB model on the  data set:   1.75
# MAPE of XGB model on the data set:   6.85
# R2 of XGB model on the  data set:   0.97
# RMSE of model on the  data set:   6.67
# MAE of XGB model on the  data set:   4.21
# MAPE of XGB model on the data set:    inf
# R2 of XGB model on the  data set:   0.84
# RMSE of model on the  data set:   5.74
# MAE of XGB model on the  data set:   3.83
# MAPE of XGB model on the data set:    inf
# R2 of XGB model on the  data set:   0.87
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# divide by zero encountered in divide
# divide by zero encountered in divide
# divide by zero encountered in divide

# %%
import matplotlib.pyplot as plt

xx = np.linspace(0, 100, 10)
yy = xx

plt.figure()
plt.plot(xx, yy, c='k', linewidth=2)
plt.scatter(y_train, Z_train, marker='s')
plt.scatter(y_test, Z_test, marker='o')
plt.scatter(y_validation, Z_validation, marker='+')

plt.grid()
plt.legend(['y=x', 'Training set', 'Testing set','Validation set'], loc = 'upper left')
plt.tick_params (axis = 'both', which = 'major')
plt.axis('tight')
plt.xlabel('Tested fc(MPa)', fontsize=20)
plt.ylabel('Predicted fc(MPa)', fontsize=20)
plt.xlim([0, 95])
plt.ylim([0, 95])
plt.title('BAS', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
plt.savefig('BAS.svg',dpi=300,bbox_inches="tight")
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
data = pd.DataFrame({'x': y_train, 'y': Z_train})

lowess = sm.nonparametric.lowess
smoothed = lowess(Z_train, y_train, frac=0.2)
x_smooth = smoothed[:, 0]
y_smooth = smoothed[:, 1]

residuals = Z_train - np.interp(y_train, x_smooth, y_smooth)
std_error = np.std(residuals)
ci = 1.96 * std_error  # 95% 置信区间

# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(x_smooth, y_smooth, label='Smoothed Line', color='#00CED1')
plt.fill_between(x_smooth, y_smooth - ci, y_smooth + ci, color='#00CED1', alpha=0.2, label='95% Confidence Interval')
plt.scatter(y_train, Z_train, color='#00CED1', s=10, alpha=0.3, label='Data Points', marker='o')

# 设置图形标题和标签
plt.title('Line Plot with LOWESS Smoothing and Confidence Interval')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# 显示图形
plt.savefig('BAS1.svg',dpi=300,bbox_inches="tight")
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
data = pd.DataFrame({'x': y_test, 'y': Z_test})

lowess = sm.nonparametric.lowess
smoothed = lowess(Z_test, y_test, frac=0.2)
x_smooth = smoothed[:, 0]
y_smooth = smoothed[:, 1]

residuals = Z_test - np.interp(y_test, x_smooth, y_smooth)
std_error = np.std(residuals)
ci = 1.96 * std_error  # 95% 置信区间

# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(x_smooth, y_smooth, label='Smoothed Line', color='#DC143C')
plt.fill_between(x_smooth, y_smooth - ci, y_smooth + ci, color='#DC143C', alpha=0.2, label='95% Confidence Interval')
plt.scatter(y_test, Z_test, color='#DC143C', s=10, alpha=0.3, label='Data Points', marker='o')

# 设置图形标题和标签
plt.title('Line Plot with LOWESS Smoothing and Confidence Interval')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# 显示图形
plt.savefig('BAS2.svg',dpi=300,bbox_inches="tight")
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
data = pd.DataFrame({'x': y_validation, 'y': Z_validation})

lowess = sm.nonparametric.lowess
smoothed = lowess(Z_validation, y_validation, frac=0.2)
x_smooth = smoothed[:, 0]
y_smooth = smoothed[:, 1]

residuals = Z_validation - np.interp(y_validation, x_smooth, y_smooth)
std_error = np.std(residuals)
ci = 1.96 * std_error  # 95% 置信区间

# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(x_smooth, y_smooth, label='Smoothed Line', color='#FF8C00')
plt.fill_between(x_smooth, y_smooth - ci, y_smooth + ci, color='#FF8C00', alpha=0.2, label='95% Confidence Interval')
plt.scatter(y_validation, Z_validation, color='#FF8C00', s=10, alpha=0.3, label='Data Points', marker='o')

# 设置图形标题和标签
plt.title('Line Plot with LOWESS Smoothing and Confidence Interval')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# 显示图形
plt.savefig('BAS3.svg',dpi=300,bbox_inches="tight")
plt.show()
